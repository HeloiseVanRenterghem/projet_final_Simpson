# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df = pd.read_excel("imdb_cleaned.xlsx", index_col=0)
df
# Out:
#     season episode  episode_serie                              title  \
# 0       S1      E1              1  Simpsons Roasting on an Open Fire
# 1       S1      E2              2                    Bart the Genius
# 2       S1      E3              3                    Homer's Odyssey
# 3       S1      E4              4      There's No Disgrace Like Home
# 4       S1      E5              5                   Bart the General
# ..     ...     ...            ...                                ...
# 722    S33     E18            723           My Octopus and a Teacher
# 723    S33     E19            724         Girls Just Shauna Have Fun
# 724    S33     E20            725                   Marge the Meanie
# 725    S33     E21            726                     Meat Is Murder
# 726    S33     E22            727                     Poorhouse Rock
#
#                                              summaries      airdates  ratings  \
# 0    Homer is forced to become a department store S...  17 Dec. 1989      8.1
# 1    Bart ends up at a school for gifted children a...  14 Jan. 1990      7.7
# 2    After losing his job, Homer contemplates endin...  21 Jan. 1990      7.3
# 3    After being embarrassed by the rest of the fam...  28 Jan. 1990      7.7
# 4    After being beaten up by Nelson Muntz one too ...   4 Feb. 1990      7.9
# ..                                                 ...           ...      ...
# 722     Bart has romantic feelings for his new teacher  24 Apr. 2022      6.6
# 723  Lisa finds an unlikely mentor in Shauna Chalme...    1 May 2022      6.6
# 724  Marge bonds with Bart when she discovers a sec...    8 May 2022      6.7
# 725  Grampa reconnects with an old associate in the...   15 May 2022      5.8
# 726  Bart finally learns to admire Homer, but a vis...   22 May 2022      5.6
#
#      total_votes                                   links  date_imdb
# 0           7529   https://www.imdb.com/title/tt0348034/ 1989-12-17
# 1           5015   https://www.imdb.com/title/tt0756593/ 1990-01-14
# 2           4427   https://www.imdb.com/title/tt0701124/ 1990-01-21
# 3           4353   https://www.imdb.com/title/tt0756399/ 1990-01-28
# 4           4687   https://www.imdb.com/title/tt0701059/ 1990-02-04
# ..           ...                                     ...        ...
# 722          348  https://www.imdb.com/title/tt14458056/ 2022-04-24
# 723          325  https://www.imdb.com/title/tt14458070/ 2022-05-01
# 724          301  https://www.imdb.com/title/tt14458078/ 2022-05-08
# 725          335  https://www.imdb.com/title/tt14458098/ 2022-05-15
# 726          515  https://www.imdb.com/title/tt14458122/ 2022-05-22
#
# [727 rows x 10 columns]

# %% [markdown]
# ## Nb d'épisodes en tout

# %%
df.shape[0]
# Out:
# 727

# %% [markdown]
# ## Nb de saisons

# %%
df["season"].nunique()
# Out:
# 33

# %% [markdown]
# ## Nb moyen d'épisodes par saison

# %%
round(df["season"].value_counts().mean())
# Out:
# 22

# %% [markdown]
# ## Répartition du nb d'épisodes par saison

# %%
df["season"] = df["season"].replace("S","", regex=True).astype(int)
df["episode"] = df["episode"].replace("E","", regex=True).astype(int)
repartition_nb_ep = df["season"].value_counts().sort_index().to_frame()
repartition_nb_ep['index'] = range(1, len(repartition_nb_ep) + 1)
repartition_nb_ep = repartition_nb_ep.set_index("index", drop=False)
repartition_nb_ep = repartition_nb_ep.rename(columns = {'index':'num_season', 'season':'nb_ep'})
repartition_nb_ep = repartition_nb_ep[['num_season', 'nb_ep']]
repartition_nb_ep
# Out:
#        num_season  nb_ep
# index
# 1               1     13
# 2               2     22
# 3               3     24
# 4               4     22
# 5               5     22
# 6               6     25
# 7               7     25
# 8               8     25
# 9               9     25
# 10             10     23
# 11             11     22
# 12             12     21
# 13             13     22
# 14             14     22
# 15             15     22
# 16             16     21
# 17             17     22
# 18             18     22
# 19             19     20
# 20             20     21
# 21             21     23
# 22             22     22
# 23             23     22
# 24             24     22
# 25             25     22
# 26             26     22
# 27             27     22
# 28             28     21
# 29             29     21
# 30             30     23
# 31             31     22
# 32             32     22
# 33             33     22

# %%
ep_color = [('#F5C024' if i == 13 else '#F15A2A' if i == 25 else '#92D4F8') for i in repartition_nb_ep['nb_ep']]

repartition_nb_ep.plot.barh(x='num_season', y='nb_ep', color=ep_color, figsize=[8,10], width=0.8).invert_yaxis()

plt.xlabel("")
plt.ylabel("Saison")

ax = plt.subplot(111)
ax.get_legend().remove()

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)

for index, value in enumerate(repartition_nb_ep["nb_ep"]):
    plt.text(value, index, str(value), va="center")

plt.title("Nombre d'épisodes par saison", x=0.5, y=1, fontweight="bold")

plt.savefig('nb_ep_par_saison.png')

plt.show()

# %% [markdown]
# ## Episodes les mieux et moins bien notés

# %%
best_ep_rating = df["ratings"].max()
df_max = df[df.ratings == best_ep_rating]
df_max
# Out:
#      season  episode  episode_serie          title  \
# 175       8       23            176  Homer's Enemy
#
#                                              summaries    airdates  ratings  \
# 175  Homer's laziness begets the ire of his industr...  4 May 1997      9.3
#
#      total_votes                                  links  date_imdb
# 175         5854  https://www.imdb.com/title/tt0701122/ 1997-05-04

# %%
print("L'épisode le mieux noté sur IMDB est l'épisode " + str(df_max.iat[0,1]) + " de la saison " + str(df_max.iat[0,0]) + " ("+ str(df_max.iat[0,2]) + "ème épisode de la série).")
print("Il a obtenu une note moyenne de " + str(df_max.iat[0,6]) + "/10 décernée par " + str(df_max.iat[0,7]) + " utilisateurs d'IMDB.")
print("Diffusé pour la première fois le " + str(df_max.iat[0,5]) + ", cet épisode s'intitule '" + str(df_max.iat[0,3]) + "'. Voici son résumé:\n" + str(df_max.iat[0,4]))
# Out:
# L'épisode le mieux noté sur IMDB est l'épisode 23 de la saison 8 (176ème épisode de la série).
# Il a obtenu une note moyenne de 9.3/10 décernée par 5854 utilisateurs d'IMDB.
# Diffusé pour la première fois le 4 May 1997, cet épisode s'intitule 'Homer's Enemy'. Voici son résumé:
# Homer's laziness begets the ire of his industrious but arrogant new co-worker Frank Grimes; Bart buys a run-down factory for a dollar.

# %%
worst_ep_rating = df["ratings"].min()
df_min = df[df.ratings == worst_ep_rating]
df_min
# Out:
#      season  episode  episode_serie           title  \
# 507      23       22            508  Lisa Goes Gaga
#
#                                              summaries     airdates  ratings  \
# 507  After a desperate attempt by Lisa to become mo...  20 May 2012      4.0
#
#      total_votes                                  links  date_imdb
# 507         2981  https://www.imdb.com/title/tt2403733/ 2012-05-20

# %%
print("L'épisode le moins bien noté sur IMDB est l'épisode " + str(df_min.iat[0,1]) + " de la saison " + str(df_min.iat[0,0]) + " ("+ str(df_min.iat[0,2]) + "ème épisode de la série).")
print("Il a obtenu une note moyenne de " + str(df_min.iat[0,6]) + "/10 décernée par " + str(df_min.iat[0,7]) + " utilisateurs d'IMDB.")
print("Diffusé pour la première fois le " + str(df_min.iat[0,5]) + ", cet épisode s'intitule '" + str(df_min.iat[0,3]) + "'. Voici son résumé:\n" + str(df_min.iat[0,4]))
# Out:
# L'épisode le moins bien noté sur IMDB est l'épisode 22 de la saison 23 (508ème épisode de la série).
# Il a obtenu une note moyenne de 4.0/10 décernée par 2981 utilisateurs d'IMDB.
# Diffusé pour la première fois le 20 May 2012, cet épisode s'intitule 'Lisa Goes Gaga'. Voici son résumé:
# After a desperate attempt by Lisa to become more popular backfires, Lady Gaga shows up in Springfield to help her with her self-esteem.

# %% [markdown]
# ## Meilleurs et pires épisodes par saison

# %%
df_best_by_season = df.loc[df.groupby("season")["ratings"].idxmax()]
df_best_by_season = df_best_by_season.drop(columns=['links', 'episode_serie', 'total_votes', 'date_imdb']).set_index('season')
df_best_by_season
# Out:
#         episode                                    title  \
# season
# 1            12                       Krusty Gets Busted
# 2            11  One Fish, Two Fish, Blowfish, Blue Fish
# 3            10                            Flaming Moe's
# 4            12                   Marge vs. the Monorail
# 5             2                               Cape Feare
# 6             6                    Treehouse of Horror V
# 7             1             Who Shot Mr. Burns? Part Two
# 8            23                            Homer's Enemy
# 9             1   The City of New York vs. Homer Simpson
# 10            2          The Wizard of Evergreen Terrace
# 11           22                      Behind the Laughter
# 12           18                         Trilogy of Error
# 13           22             Papa's Got a Brand New Badge
# 14            1                 Treehouse of Horror XIII
# 15            1                  Treehouse of Horror XIV
# 16           16                    Don't Fear the Roofer
# 17           13         The Seemingly Never-Ending Story
# 18           21                               24 Minutes
# 19            9    Eternal Moonshine of the Simpson Mind
# 20           21                       Coming to Homerica
# 21            4                   Treehouse of Horror XX
# 22           21                                 500 Keys
# 23            9                Holidays of Future Passed
# 24            2                Treehouse of Horror XXIII
# 25           20                            Brick Like Me
# 26            6                               Simpsorama
# 27            9                                 Barthood
# 28            3                                 The Town
# 29           21                         Flanders' Ladder
# 30            5              Baby You Can't Drive My Car
# 31           22                       The Way of the Dog
# 32           22                      The Last Barfighter
# 33            6                       A Serious Flanders
#
#                                                 summaries      airdates  \
# season
# 1       After Krusty is found guilty of robbing the Kw...  29 Apr. 1990
# 2       After apparently consuming poison blowfish, Ho...  24 Jan. 1991
# 3       Moe claims a drink that Homer invented is his ...  21 Nov. 1991
# 4       After receiving a considerable donation of mon...  14 Jan. 1993
# 5       After being released from prison on parole, Si...   7 Oct. 1993
# 6       The family's job at Mr. Burns' country estate ...  30 Oct. 1994
# 7       Mr. Burns is laying in the hospital while the ...  17 Sep. 1995
# 8       Homer's laziness begets the ire of his industr...    4 May 1997
# 9       Homer must travel to New York to get his car b...  21 Sep. 1997
# 10      Homer's midlife crisis leads to a disastrous a...  20 Sep. 1998
# 11      Fans are invited to take a behind-the-scenes l...   21 May 2000
# 12      Homer's rush to the hospital to re-attach his ...  29 Apr. 2001
# 13      Homer becomes chief of police after a scandal ...   22 May 2002
# 14      Homer clones himself with a magic hammock; Zom...   3 Nov. 2002
# 15      First, Homer kills the Grim Reaper and takes h...   2 Nov. 2003
# 16      Homer meets a new friend, Ray the Roofer, but ...    1 May 2005
# 17      In this story within a story within a story wi...  12 Mar. 2006
# 18      Bart and Lisa join forces to stop the school b...   20 May 2007
# 19      Homer goes to Dr. Frink to help him recover hi...  16 Dec. 2007
# 20      Townspeople build a wall around Springfield to...   17 May 2009
# 21      Lisa becomes livid with Miss Hoover, and in a ...  18 Oct. 2009
# 22      While Homer takes the Duff Blimp for a joyride...   15 May 2011
# 23      Thirty years in the future the Simpsons get to...  11 Dec. 2011
# 24      A black hole threatens to swallow Springfield,...   7 Oct. 2012
# 25      The Lego version of Homer begins to suspect th...    4 May 2014
# 26      The Simpsons meet the Planet Express crew, who...   9 Nov. 2014
# 27      A tale of Bart's journey from youth to adultho...  13 Dec. 2015
# 28      Homer takes the family on a "hate-cation" to B...   9 Oct. 2016
# 29      When Bart falls into a coma after he is struck...   20 May 2018
# 30      A self-driving car company comes to Springfiel...   4 Nov. 2018
# 31      The Simpsons explore the tragic past of Santa'...   17 May 2020
# 32      A secret society of bartenders seeks revenge o...   23 May 2021
# 33      Homer and Ned get sucked into the violent worl...   7 Nov. 2021
#
#         ratings
# season
# 1           8.3
# 2           8.8
# 3           8.8
# 4           9.1
# 5           9.1
# 6           9.2
# 7           9.0
# 8           9.3
# 9           9.0
# 10          8.1
# 11          7.9
# 12          8.6
# 13          7.8
# 14          7.6
# 15          7.5
# 16          7.5
# 17          7.6
# 18          8.1
# 19          8.2
# 20          7.3
# 21          7.3
# 22          7.3
# 23          8.3
# 24          7.2
# 25          7.9
# 26          7.9
# 27          8.4
# 28          7.0
# 29          7.5
# 30          6.9
# 31          7.4
# 32          7.4
# 33          8.2

# %%
print(df_best_by_season.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>episode</th>
#       <th>title</th>
#       <th>summaries</th>
#       <th>airdates</th>
#       <th>ratings</th>
#     </tr>
#     <tr>
#       <th>season</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>12</td>
#       <td>Krusty Gets Busted</td>
#       <td>After Krusty is found guilty of robbing the Kwik-E-Mart following Homer's eyewitness testimony, Bart and Lisa set out to prove his innocence.</td>
#       <td>29 Apr. 1990</td>
#       <td>8.3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11</td>
#       <td>One Fish, Two Fish, Blowfish, Blue Fish</td>
#       <td>After apparently consuming poison blowfish, Homer is told that he only has 24 hours to live.</td>
#       <td>24 Jan. 1991</td>
#       <td>8.8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10</td>
#       <td>Flaming Moe's</td>
#       <td>Moe claims a drink that Homer invented is his own, with the drink making the bar a local hot spot, but threatens his friendship with Homer.</td>
#       <td>21 Nov. 1991</td>
#       <td>8.8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>12</td>
#       <td>Marge vs. the Monorail</td>
#       <td>After receiving a considerable donation of money, Springfield builds a monorail system with Homer as the conductor, unaware they've just boarded a one-way train to Hell.</td>
#       <td>14 Jan. 1993</td>
#       <td>9.1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>Cape Feare</td>
#       <td>After being released from prison on parole, Sideshow Bob plots to murder Bart.</td>
#       <td>7 Oct. 1993</td>
#       <td>9.1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td
# 24      Homer's obsession with the TV show "Storage Ba...   3 Mar. 2013
# 25      Bart becomes a savior to Springfield couples t...  27 Apr. 2014
# 26      Inventor Elon Musk comes to Springfield, and H...  25 Jan. 2015
# 27      Marge decides it's finally time to separate fr...  27 Sep. 2015
# 28      Krusty and his daughter spend Christmas with t...  11 Dec. 2016
# 29      Bart goes to prankster rehab after a clown-mas...   1 Apr. 2018
# 30      Bart's friends start a boys rights activist gr...  24 Mar. 2019
# 31      Marge becomes a competitive lumberjack and goe...  10 Nov. 2019
# 32      Cletus becomes a singing sensation and ruins e...   7 Mar. 2021
# 33      Marge stages a revival of a musical from high ...  26 Sep. 2021
#
#         ratings
# season
# 1           7.3
# 2           7.4
# 3           7.6
# 4           7.0
# 5           7.5
# 6           5.8
# 7           7.4
# 8           7.1
# 9           5.0
# 10          7.0
# 11          6.5
# 12          6.7
# 13          5.5
# 14          6.6
# 15          6.4
# 16          6.3
# 17          6.2
# 18          6.0
# 19          6.1
# 20          6.0
# 21          5.7
# 22          6.1
# 23          4.0
# 24          6.2
# 25          5.8
# 26          5.6
# 27          5.7
# 28          5.9
# 29          6.0
# 30          4.9
# 31          5.6
# 32          5.5
# 33          4.3

# %%
print(df_worst_by_season.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>episode</th>
#       <th>title</th>
#       <th>summaries</th>
#       <th>airdates</th>
#       <th>ratings</th>
#     </tr>
#     <tr>
#       <th>season</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>Homer's Odyssey</td>
#       <td>After losing his job, Homer contemplates ending it all, until he discovers a new life path as a safety advocate.</td>
#       <td>21 Jan. 1990</td>
#       <td>7.3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>Dancin' Homer</td>
#       <td>Homer's heckling of the Springfield Isotopes baseball team during one of their games inadvertently leads to his appointment as the new team mascot.</td>
#       <td>8 Nov. 1990</td>
#       <td>7.4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>Like Father, Like Clown</td>
#       <td>Bart and Lisa try to reunite Krusty the Clown with his father.</td>
#       <td>24 Oct. 1991</td>
#       <td>7.6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18</td>
#       <td>So It's Come to This: A Simpsons Clip Show</td>
#       <td>As Homer recovers in hospital due to Bart's disastrous April Fool's Day prank, the family reminiscences over earlier hardships.</td>
#       <td>1 Apr. 1993</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>21</td>
#       <td>Lady Bouvier's Lover</td>
#       <td>Grampa falls in love with Marge's mother, but must compete with Mr. Burns for her heart.</td>
#       <td>12 May 1994</td>
#       <td>7.5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>Another Simpsons Clip Show</td>
#       <td>The family recalls past tales of lost love.</td>
#       <td>25 Sep. 1994</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>10</td>
#       <td>The Simpsons 138th Episode Spectacular!</td>
#       <td>Troy McClure hosts a retrospective of the first 137 episodes of Les Simpson (1989).</td>
#       <td>3 Dec. 1995</td>
#       <td>7.4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>24</td>
#       <td>The Simpsons Spin-Off Showcase</td>
#       <td>Troy McClure presents three spinoffs: "Chief Wiggins, P.I.," "The Love-Matic Grandpa," and "The Simpson Family Smile-Time Variety Hour."</td>
#       <td>11 May 1997</td>
#       <td>7.1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>11</td>
#       <td>All Singing, All Dancing</td>
#       <td>Homer is disappointed when the western he rented turns out to be a musical, so the family reminds him of the musical moments in the show's history.</td>
#       <td>4 Jan. 1998</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td
td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>14</td>
#       <td>Gorgeous Grampa</td>
#       <td>Homer's obsession with the TV show "Storage Battles" leads the family to discover Grampa's past identity as "Gorgeous Godfrey," the most feared, villainous man in pro-wrestling history.</td>
#       <td>3 Mar. 2013</td>
#       <td>6.2</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>19</td>
#       <td>What to Expect When Bart's Expecting</td>
#       <td>Bart becomes a savior to Springfield couples trying to conceive when he inadvertently uses voodoo to get his art teacher pregnant.</td>
#       <td>27 Apr. 2014</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>12</td>
#       <td>The Musk Who Fell to Earth</td>
#       <td>Inventor Elon Musk comes to Springfield, and Homer inspires him with a new idea that could revolutionize Springfield, but winds up costing Mr. Burns a ton of money.</td>
#       <td>25 Jan. 2015</td>
#       <td>5.6</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1</td>
#       <td>Every Man's Dream</td>
#       <td>Marge decides it's finally time to separate from Homer, and quickly moves on with her life. Homer is initially devastated, but soon stumbles into a romance with a younger woman.</td>
#       <td>27 Sep. 2015</td>
#       <td>5.7</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>10</td>
#       <td>The Nightmare After Krustmas</td>
#       <td>Krusty and his daughter spend Christmas with the Simpsons; Reverend Lovejoy seeks converts to boost attendance at church; A Christmas toy scares Maggie.</td>
#       <td>11 Dec. 2016</td>
#       <td>5.9</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>14</td>
#       <td>Fears of a Clown</td>
#       <td>Bart goes to prankster rehab after a clown-mask prank terrifies the town and ruins Krusty's career causing him to give up comedy and try serious drama.</td>
#       <td>1 Apr. 2018</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>18</td>
#       <td>Bart vs. Itchy &amp; Scratchy</td>
#       <td>Bart's friends start a boys rights activist group to protest Krusty's all-female reboot of Itchy and Scratchy. When they catch Bart enjoying it, they kick him out, so he joins Bossy Riot, a militant feminist gang of sixth-grade girls.</td>
#       <td>24 Mar. 2019</td>
#       <td>4.9</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>6</td>
#       <td>Marge the Lumberjill</td>
#       <td>Marge becomes a competitive lumberjack and goes on a month-long retreat to Portland with her trainer, whom Homer fears will take his wife away from him.</td>
#       <td>10 Nov. 2019</td>
#       <td>5.6</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>14</td>
#       <td>Yokel Hero</td>
#       <td>Cletus becomes a singing sensation and ruins everything when he turns on his fans, while Homer becomes a new man.</td>
#       <td>7 Mar. 2021</td>
#       <td>5.5</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1</td>
#       <td>The Star of the Backstage</td>
#       <td>Marge stages a revival of a musical from high school, but her pleasant memories are threatened by the return of her old rival.</td>
#       <td>26 Sep. 2021</td>
#       <td>4.3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Evolution des notes moyennes par saison

# %%
avr_ratings = df[["season", "ratings", "total_votes"]]
avr_ratings = avr_ratings.groupby('season').mean()
avr_ratings['index'] = range(1, len(avr_ratings) + 1)
avr_ratings = avr_ratings.set_index("index", drop=False)
avr_ratings = avr_ratings.rename(columns = {'index':'season'})
avr_ratings
# Out:
#         ratings  total_votes  season
# index
# 1      7.707692  4474.846154       1
# 2      8.004545  3593.681818       2
# 3      8.154167  3268.500000       3
# 4      8.272727  3307.500000       4
# 5      8.318182  3165.227273       5
# 6      8.344000  3056.160000       6
# 7      8.364000  2930.360000       7
# 8      8.224000  3006.920000       8
# 9      7.824000  2413.000000       9
# 10     7.595652  2057.565217      10
# 11     7.304545  1835.363636      11
# 12     7.323810  1842.571429      12
# 13     7.081818  1626.181818      13
# 14     7.036364  1517.272727      14
# 15     7.000000  1445.636364      15
# 16     6.980952  1388.333333      16
# 17     6.822727  1404.772727      17
# 18     6.927273  1461.863636      18
# 19     6.895000  1450.400000      19
# 20     6.885714  1359.095238      20
# 21     6.795652  1230.086957      21
# 22     6.727273  1177.454545      22
# 23     6.740909  1335.136364      23
# 24     6.718182  1062.863636      24
# 25     6.754545  1146.818182      25
# 26     6.609091  1082.681818      26
# 27     6.640909  1011.409091      27
# 28     6.423810   846.380952      28
# 29     6.571429   876.428571      29
# 30     6.156522   841.260870      30
# 31     6.418182   766.863636      31
# 32     6.363636   690.954545      32
# 33     6.518182   509.000000      33

# %%
plt.figure(figsize=(13,7))

plt.plot(avr_ratings["season"], avr_ratings["ratings"], color='#92D4F8', linewidth=5, label=None)

plt.xlim([1, 33])
plt.locator_params(axis='x', nbins=33)

plt.xlabel('Saison')
plt.ylabel('Notes IMDB moyennes')

plt.grid(axis='y', alpha=.4,linestyle='--')

plt.title("Evolution des notes IMDB", x=0.5, y=1, fontweight="bold")

plt.savefig('evol_notes.png')

plt.show()

# %% [markdown]
# ## Evolution du nombre moyen d'avis par saison

# %%
plt.figure(figsize=(13,7))

plt.plot(avr_ratings["season"], avr_ratings["total_votes"], color='#92D4F8', linewidth=5, label=None)

plt.xlim([1, 33])
plt.locator_params(axis='x', nbins=33)

plt.xlabel('Saison')
plt.ylabel('Nombre moyen de votes sur IMDB')

plt.grid(axis='y', alpha=.4,linestyle='--')

plt.title("Evolution du nombre moyen de votes sur IMDB", x=0.5, y=1, fontweight="bold")

plt.savefig('evol_nb_notes.png')

plt.show()

# %% [markdown]
# ## Nb de télespectateurs

# %%
df_kaggle0 = pd.read_csv("simpsons_episodes.csv")
df_kaggle0
# Out:
#       id                                          image_url  imdb_rating  \
# 0     10  http://static-media.fxx.com/img/FX_Networks_-_...          7.4
# 1     12  http://static-media.fxx.com/img/FX_Networks_-_...          8.3
# 2     14  http://static-media.fxx.com/img/FX_Networks_-_...          8.2
# 3     17  http://static-media.fxx.com/img/FX_Networks_-_...          8.1
# 4     19  http://static-media.fxx.com/img/FX_Networks_-_...          8.0
# ..   ...                                                ...          ...
# 595  500  http://static-media.fxx.com/img/FX_Networks_-_...          7.0
# 596  502  http://static-media.fxx.com/img/FX_Networks_-_...          7.3
# 597  511  http://static-media.fxx.com/img/FX_Networks_-_...          6.9
# 598  542  http://static-media.fxx.com/img/FX_Networks_-_...          6.4
# 599  548  http://static-media.fxx.com/img/FX_Networks_-_...          7.0
#
#      imdb_votes  number_in_season  number_in_series original_air_date  \
# 0        1511.0                10                10        1990-03-25
# 1        1716.0                12                12        1990-04-29
# 2        1638.0                 1                14        1990-10-11
# 3        1457.0                 4                17        1990-11-01
# 4        1366.0                 6                19        1990-11-15
# ..          ...               ...               ...               ...
# 595       580.0                14               500        2012-02-19
# 596       541.0                16               502        2012-03-11
# 597       460.0                 3               511        2012-11-04
# 598       473.0                12               542        2014-03-09
# 599       504.0                18               548        2014-04-13
#
#      original_air_year production_code  season  \
# 0                 1990            7G10       1
# 1                 1990            7G12       1
# 2                 1990            7F03       2
# 3                 1990            7F01       2
# 4                 1990            7F08       2
# ..                 ...             ...     ...
# 595               2012          PABF07      23
# 596               2012          PABF08      23
# 597               2012          PABF18      24
# 598               2014          SABF08      25
# 599               2014          SABF13      25
#
#                                                  title  \
# 0                                    Homer's Night Out
# 1                                   Krusty Gets Busted
# 2                                     Bart Gets an "F"
# 3    Two Cars in Every Garage and Three Eyes on Eve...
# 4                                 Dead Putting Society
# ..                                                 ...
# 595                                 At Long Last Leave
# 596                              How I Wet Your Mother
# 597                         Adventures in Baby-Getting
# 598                                              Diggs
# 599                              Days of Future Future
#
#      us_viewers_in_millions                                        video_url  \
# 0                     30.30  http://www.simpsonsworld.com/video/275197507879
# 1                     30.40  http://www.simpsonsworld.com/video/288019523914
# 2                     33.60  http://www.simpsonsworld.com/video/260539459671
# 3                     26.10  http://www.simpsonsworld.com/video/260537411822
# 4                     25.40  http://www.simpsonsworld.com/video/260539459670
# ..                      ...                                              ...
# 595                    5.77  http://www.simpsonsworld.com/video/230541891832
# 596                    4.97  http://www.simpsonsworld.com/video/230597187582
# 597                    5.65  http://www.simpsonsworld.com/video/221688899646
# 598                    2.69  http://www.simpsonsworld.com/video/310529091639
# 599                    3.64  http://www.simpsonsworld.com/video/310257731892
#
#        views
# 0    50816.0
# 1    62561.0
# 2    59575.0
# 3    64959.0
# 4    50691.0
# ..       ...
# 595  45226.0
# 596  44818.0
# 597  39687.0
# 598  39292.0
# 599  55742.0
#
# [600 rows x 14 columns]

# %%
df_kaggle0["us_viewers_in_millions"].sum()
# Out:
# 7034.620000000001

# %%
df_kaggle0["us_viewers_in_millions"].mean()
# Out:
# 11.842794612794606

# %% [markdown]
# ## Episodes avec le plus et le moins de télespectateurs

# %%
most_viewed_ep = df_kaggle0["us_viewers_in_millions"].max()
df_most_viewed_ep = df_kaggle0[df_kaggle0["us_viewers_in_millions"] == most_viewed_ep]
df_most_viewed_ep
# Out:
#    id                                          image_url  imdb_rating  \
# 2  14  http://static-media.fxx.com/img/FX_Networks_-_...          8.2
#
#    imdb_votes  number_in_season  number_in_series original_air_date  \
# 2      1638.0                 1                14        1990-10-11
#
#    original_air_year production_code  season             title  \
# 2               1990            7F03       2  Bart Gets an "F"
#
#    us_viewers_in_millions                                        video_url  \
# 2                    33.6  http://www.simpsonsworld.com/video/260539459671
#
#      views
# 2  59575.0

# %%
less_viewed_ep = df_kaggle0["us_viewers_in_millions"].min()
df_less_viewed_ep = df_kaggle0[df_kaggle0["us_viewers_in_millions"] == less_viewed_ep]
df_less_viewed_ep
# Out:
#       id                                          image_url  imdb_rating  \
# 518  591  http://static-media.fxx.com/img/FX_Networks_-_...          6.5
#
#      imdb_votes  number_in_season  number_in_series original_air_date  \
# 518       246.0                17               591        2016-04-03
#
#      original_air_year production_code  season           title  \
# 518               2016          VABF10      27  The Burns Cage
#
#      us_viewers_in_millions                                        video_url  \
# 518                    2.32  http://www.simpsonsworld.com/video/770893891557
#
#      views
# 518  190.0

# %% [markdown]
# ## Episodes avec le plus et le moins de télespectateurs par saison

# %%
df_most_viewed_by_season = df_kaggle0.loc[df_kaggle0.groupby("season")["us_viewers_in_millions"].idxmax()]
df_most_viewed_by_season = df_most_viewed_by_season.drop(columns=['id', 'image_url', 'imdb_rating', 'imdb_votes', 'original_air_year', 'production_code', 'video_url', 'views']).set_index('season')
df_most_viewed_by_season
# Out:
#         number_in_season  number_in_series original_air_date  \
# season
# 1                      9                 9        1990-03-18
# 2                      1                14        1990-10-11
# 3                     20                55        1992-03-26
# 4                     10                69        1992-12-03
# 5                      5                86        1993-10-28
# 6                      6               109        1994-10-30
# 7                      6               134        1995-10-29
# 8                     10               163        1997-01-12
# 9                      2               180        1997-09-28
# 10                    17               220        1999-03-28
# 11                    12               238        2000-01-23
# 12                    11               259        2001-02-04
# 13                     2               271        2001-11-11
# 14                    12               303        2003-02-16
# 15                     9               322        2004-01-11
# 16                     8               343        2005-02-06
# 17                     4               360        2005-11-06
# 18                    10               388        2007-01-07
# 19                     5               405        2007-11-04
# 20                     4               424        2008-11-02
# 21                    10               451        2010-01-10
# 22                    10               474        2011-01-09
# 23                    11               497        2012-01-15
# 24                     9               517        2013-01-06
# 25                     9               539        2014-01-05
# 26                    10               562        2015-01-04
# 27                    11               585        2016-01-10
# 28                     1               597        2016-09-25
#
#                                      title  us_viewers_in_millions
# season
# 1                    Life on the Fast Lane                   33.50
# 2                         Bart Gets an "F"                   33.60
# 3                            Colonel Homer                   25.50
# 4                        Lisa's First Word                   28.60
# 5                   Treehouse of Horror IV                   24.00
# 6                    Treehouse of Horror V                   22.20
# 7                   Treehouse of Horror VI                   19.70
# 8                    The Springfield Files                   20.90
# 9             The Principal and the Pauper                   14.90
# 10                      Maximum Homerdrive                   15.50
# 11                      The Mansion Family                   11.30
# 12                      Worst Episode Ever                   18.50
# 13                          The Parent Rap                   14.90
# 14           I'm Spelling As Fast As I Can                   22.10
# 15                  I, (Annoyed Grunt)-bot                   16.30
# 16          Homer and Ned's Hail Mary Pass                   23.07
# 17                 Treehouse of Horror XVI                   11.63
# 18                        The Wife Aquatic                   13.90
# 19               Treehouse of Horror XVIII                   11.70
# 20                 Treehouse of Horror XIX                   12.48
# 21         Once Upon a Time in Springfield                   14.62
# 22                 Moms I'd Like to Forget                   12.60
# 23                   The D'oh-cial Network                   11.48
# 24               Homer Goes to Prep School                    8.97
# 25                      Steal This Episode                   12.04
# 26           The Man Who Came to Be Dinner                   10.62
# 27      Teenage Mutant Milk-Caused Hurdles                    8.33
# 28             Monty Burns' Fleeing Circus                    3.36

# %%
print(df_most_viewed_by_season.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>number_in_season</th>
#       <th>number_in_series</th>
#       <th>original_air_date</th>
#       <th>title</th>
#       <th>us_viewers_in_millions</th>
#     </tr>
#     <tr>
#       <th>season</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>9</td>
#       <td>9</td>
#       <td>1990-03-18</td>
#       <td>Life on the Fast Lane</td>
#       <td>33.50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td
td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1</td>
#       <td>597</td>
#       <td>2016-09-25</td>
#       <td>Monty Burns' Fleeing Circus</td>
#       <td>3.36</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_less_viewed_by_season = df_kaggle0.loc[df_kaggle0.groupby("season")["us_viewers_in_millions"].idxmin()]
df_less_viewed_by_season = df_less_viewed_by_season.drop(columns=['id', 'image_url', 'imdb_rating', 'imdb_votes', 'original_air_year', 'production_code', 'video_url', 'views']).set_index('season')
df_less_viewed_by_season
# Out:
#         number_in_season  number_in_series original_air_date  \
# season
# 1                      4                 4        1990-01-28
# 2                     22                35        1991-07-11
# 3                     24                59        1992-08-27
# 4                     21                80        1993-05-06
# 5                     18                99        1994-04-14
# 6                     20               123        1995-04-09
# 7                     21               149        1996-04-14
# 8                     12               165        1997-02-02
# 9                     20               198        1998-04-05
# 10                    22               225        1999-05-09
# 11                     3               229        1999-10-24
# 12                    19               267        2001-05-06
# 13                    22               291        2002-05-22
# 14                    20               311        2003-05-11
# 15                    20               333        2004-05-09
# 16                    14               349        2005-04-03
# 17                    18               374        2006-04-23
# 18                    17               395        2007-04-22
# 19                    19               419        2008-05-11
# 20                    20               440        2009-05-10
# 21                    11               452        2010-01-31
# 22                    18               482        2011-04-10
# 23                    21               507        2012-05-13
# 24                     8               516        2012-12-16
# 25                    12               542        2014-03-09
# 26                    14               566        2015-02-15
# 27                    17               591        2016-04-03
# 28                     1               597        2016-09-25
#
#                                           title  us_viewers_in_millions
# season
# 1                 There's No Disgrace Like Home                   20.20
# 2                                    Blood Feud                   17.30
# 3             Brother, Can You Spare Two Dimes?                   17.20
# 4                               Marge in Chains                   17.30
# 5                                   Burns' Heir                   14.70
# 6                  Two Dozen and One Greyhounds                   11.60
# 7              22 Short Films About Springfield                   10.50
# 8                           Mountain of Madness                    9.10
# 9                    The Trouble with Trillions                    7.40
# 10                      They Saved Lisa's Brain                    6.80
# 11      Guess Who's Coming to Criticize Dinner?                    6.70
# 12                      I'm Goin' to Praiseland                   13.10
# 13                Poppa's Got a Brand New Badge                    8.20
# 14                        Brake My Wife, Please                   10.56
# 15                           The Way We Weren't                    6.60
# 16                        The Seven-Beer Snitch                    7.48
# 17                The Wettest Stories Ever Told                    7.04
# 18                                  Marge Gamer                    6.40
# 19                                Mona Leaves-a                    6.02
# 20              Four Great Women and a Manicure                    5.16
# 21                         Million Dollar Maybe                    5.11
# 22                           The Great Simpsina                    4.99
# 23                          Ned 'n Edna's Blend                    4.07
# 24                             To Cur with Love                    3.77
# 25                                        Diggs                    2.69
# 26                                 My Fare Lady                    2.67
# 27                               The Burns Cage                    2.32
# 28                  Monty Burns' Fleeing Circus                    3.36

# %%
print(df_less_viewed_by_season.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>number_in_season</th>
#       <th>number_in_series</th>
#       <th>original_air_date</th>
#       <th>title</th>
#       <th>us_viewers_in_millions</th>
#     </tr>
#     <tr>
#       <th>season</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>4</td>
#       <td>1990-01-28</td>
#       <td>There's No Disgrace Like Home</td>
#       <td>20.20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>22</td>
#       <td>35</td>
#       <td>1991-07-11</td>
#       <td>Blood Feud</td>
#       <td>17.30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td
td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Evolution du nb de télespectateurs

# %%
df_kaggle = df_kaggle0[["season", "imdb_rating", "imdb_votes", "us_viewers_in_millions"]]
df_kaggle = df_kaggle.groupby('season').mean()
df_kaggle['index'] = range(1, len(df_kaggle) + 1)
df_kaggle = df_kaggle.set_index("index", drop=False)
df_kaggle = df_kaggle.rename(columns = {'index':'season'})
df_kaggle
# Out:
#        imdb_rating   imdb_votes  us_viewers_in_millions  season
# index
# 1         7.807692  1819.384615               27.807692       1
# 2         8.040909  1416.454545               24.404545       2
# 3         8.154167  1311.916667               21.766667       3
# 4         8.268182  1347.500000               22.395455       4
# 5         8.336364  1264.545455               18.940909       5
# 6         8.312000  1235.240000               15.596000       6
# 7         8.324000  1184.560000               14.660000       7
# 8         8.220000  1233.560000               14.600000       8
# 9         7.844000  1013.360000               10.008000       9
# 10        7.569565   880.000000                8.737391      10
# 11        7.290909   792.136364                8.772273      11
# 12        7.361905   771.619048               15.485714      12
# 13        7.140909   673.727273               12.463636      13
# 14        7.077273   626.818182               14.378182      14
# 15        7.045455   599.409091               10.987273      15
# 16        7.042857   576.476190               10.373333      16
# 17        6.863636   600.590909                9.548636      17
# 18        7.000000   655.727273                9.149545      18
# 19        6.935000   678.150000                8.280500      19
# 20        6.895238   635.809524                7.070476      20
# 21        6.821739   544.434783                7.134783      21
# 22        6.804545   513.954545                7.092273      22
# 23        6.813636   579.636364                6.148182      23
# 24        6.777273   440.363636                5.411818      24
# 25        6.831818   486.000000                5.019091      25
# 26        6.704545   451.863636                4.804545      26
# 27        6.786364   325.136364                4.000455      27
# 28        6.600000   104.000000                3.360000      28

# %%
plt.figure(figsize=(13,7))

plt.plot(df_kaggle["season"], df_kaggle["us_viewers_in_millions"], color='#92D4F8', linewidth=5, label=None)

plt.xlim([1, 28])
plt.locator_params(axis='x', nbins=28)

plt.xlabel('Saison')
plt.ylabel('Nombre moyen de télespectateurs US (millions)')

plt.grid(axis='y', alpha=.4,linestyle='--')

plt.title("Evolution du nombre de télespectateurs US", x=0.5, y=1, fontweight="bold")

plt.savefig('evol_viewers.png')

plt.show()

# %% [markdown]
# ## Corrélation note/nb avis

# %%
plt.figure(figsize=(10,10))

plt.scatter(df_kaggle0["imdb_rating"],df_kaggle0["imdb_votes"], s=600, c='#C22E6B', alpha=0.8, marker=r'$°$')

plt.xlabel("Note sur IMDB")
plt.ylabel("Nombre d'avis sur IMDB")

plt.ylim([1, 4000])

plt.title("Corrélation entre la note sur IMDB et le nombre d'avis sur IMDB", x=0.5, y=1, fontweight="bold")

plt.savefig('correl_ratings_nb_ratings.png')

plt.show()

# %% [markdown]
# ## Corrélation note/nb télespectateurs

# %%
plt.figure(figsize=(10,10))

plt.scatter(df_kaggle0["imdb_rating"],df_kaggle0["us_viewers_in_millions"], s=100, c='#F15A2A', alpha=0.8, marker='o')

plt.xlabel('Note sur IMDB')
plt.ylabel('Nombre de télespectateurs US (millions)')

plt.ylim([1, 35])

plt.title("Corrélation entre la note IMDB et le nombre de télespectateurs US", x=0.5, y=1, fontweight="bold")

plt.savefig('correl_ratings_viewers.png')

plt.show()
