# %%
import pandas as pd

# %%
df = pd.read_excel("imdb_cleaned.xlsx", index_col=0)
df
# Out:
#     season episode  episode_serie                              title  \
# 0       S1      E1              1  Simpsons Roasting on an Open Fire
# 1       S1      E2              2                    Bart the Genius
# 2       S1      E3              3                    Homer's Odyssey
# 3       S1      E4              4      There's No Disgrace Like Home
# 4       S1      E5              5                   Bart the General
# ..     ...     ...            ...                                ...
# 722    S33     E18            723           My Octopus and a Teacher
# 723    S33     E19            724         Girls Just Shauna Have Fun
# 724    S33     E20            725                   Marge the Meanie
# 725    S33     E21            726                     Meat Is Murder
# 726    S33     E22            727                     Poorhouse Rock
#
#                                              summaries      airdates  \
# ...

# %%
df["Episode"] = df["season"] + df["episode"]

# %%
df = df.drop(columns=["season", "episode", "episode_serie", "date_imdb"])

# %%
df = df.rename(columns={"title": "Titre", "summaries": "Résumé", "airdates": "Date de sortie", "ratings": "Note IMDB", "total_votes": "Nombre d'avis IMDB", "links": "Lien vers l'épisode"})
df
# Out:
#                                  Titre  \
# 0    Simpsons Roasting on an Open Fire
# 1                      Bart the Genius
# 2                      Homer's Odyssey
# 3        There's No Disgrace Like Home
# 4                     Bart the General
# ..                                 ...
# 722           My Octopus and a Teacher
# 723         Girls Just Shauna Have Fun
# 724                   Marge the Meanie
# 725                     Meat Is Murder
# 726                     Poorhouse Rock
#
#                                                 Résumé Date de sortie  \
# 0    Homer is forced to become a department store S...   17 Dec. 1989
# 1    Bart ends up at a school for gifted children a...   14 Jan. 1990
# 2    After losing his job, Homer contemplates endin...   21 Jan. 1990
# 3    After being embarrassed by the rest of the fam...   28 Jan. 1990
# 4    After being beaten up by Nelson Muntz one too ...    4 Feb. 1990
# ...

# %%
df_S1 = df[df["Episode"].str.startswith('S1E')]
df_S1 = df_S1.set_index('Episode')
S1 = df_S1.to_html()
print(S1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S1E1</th>
#       <td>Simpsons Roasting on an Open Fire</td>
#       <td>Homer is forced to become a department store Santa when Marge spends the family's Christmas savings on removing Bart's tattoo.</td>
#       <td>17 Dec. 1989</td>
#       <td>8.1</td>
#       <td>7529</td>
#       <td>https://www.imdb.com/title/tt0348034/</td>
#     </tr>
#     <tr>
#       <th>S1E2</th>
#       <td>Bart the Genius</td>
# ...

# %%
df_S2 = df[df["Episode"].str.startswith('S2E')]
df_S2 = df_S2.set_index('Episode')
S2 = df_S2.to_html()
print(S2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S2E1</th>
#       <td>Bart Gets an F</td>
#       <td>Mrs. Krabappel, fed up with Bart's lackadaisical approach to his studies, gives him an ultimatum: shape up or repeat the fourth grade.</td>
#       <td>11 Oct. 1990</td>
#       <td>8.2</td>
#       <td>4223</td>
#       <td>https://www.imdb.com/title/tt0763024/</td>
#     </tr>
#     <tr>
#       <th>S2E2</th>
#       <td>Simpson and Delilah</td>
# ...

# %%
df_S3 = df[df["Episode"].str.startswith('S3E')]
df_S3 = df_S3.set_index('Episode')
S3 = df_S3.to_html()
print(S3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S3E1</th>
#       <td>Stark Raving Dad</td>
#       <td>Homer accidentally lands in a mental hospital and ends up sharing a room with a white man who thinks he is Michael Jackson.</td>
#       <td>19 Sep. 1991</td>
#       <td>8.6</td>
#       <td>4398</td>
#       <td>https://www.imdb.com/title/tt0701217/</td>
#     </tr>
#     <tr>
#       <th>S3E2</th>
#       <td>Mr. Lisa Goes to Washington</td>
# ...

# %%
df_S4 = df[df["Episode"].str.startswith('S4E')]
df_S4 = df_S4.set_index('Episode')
S4 = df_S4.to_html()
print(S4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S4E1</th>
#       <td>Kamp Krusty</td>
#       <td>Bart and Lisa attend "Kamp Krusty" but it is nothing like they thought it would be</td>
#       <td>24 Sep. 1992</td>
#       <td>8.5</td>
#       <td>3503</td>
#       <td>https://www.imdb.com/title/tt0701142/</td>
#     </tr>
#     <tr>
#       <th>S4E2</th>
#       <td>A Streetcar Named Marge</td>
#       <td>Marge stars in a musical adaptation of A Streetcar Named Desire, but is angry with Homer's lack of interest</td>
# ...

# %%
df_S5 = df[df["Episode"].str.startswith('S5E')]
df_S5 = df_S5.set_index('Episode')
S5 = df_S5.to_html()
print(S5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S5E1</th>
#       <td>Homer's Barbershop Quartet</td>
#       <td>After the kids find a record with Homer's picture on it, he recalls the story of how he achieved fame in the 1980s with his barbershop quartet, The Be Sharps.</td>
#       <td>30 Sep. 1993</td>
#       <td>8.5</td>
#       <td>3471</td>
#       <td>https://www.imdb.com/title/tt0701121/</td>
#     </tr>
#     <tr>
#       <th>S5E2</th>
#       <td>Cape Feare</td>
# ...

# %%
df_S6 = df[df["Episode"].str.startswith('S6E')]
df_S6 = df_S6.set_index('Episode')
S6 = df_S6.to_html()
print(S6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S6E1</th>
#       <td>Bart of Darkness</td>
#       <td>Confined to his room with a broken leg, Bart suspects Ned Flanders of murdering Maude</td>
#       <td>4 Sep. 1994</td>
#       <td>8.7</td>
#       <td>3318</td>
#       <td>https://www.imdb.com/title/tt0763026/</td>
#     </tr>
#     <tr>
#       <th>S6E2</th>
#       <td>Lisa's Rival</td>
#       <td>Lisa is jealous when a new girl in class is smarter than she is</td>
#       <td>11 Sep. 1994</td>
#       <td>8.1</td>
# ...

# %%
df_S7 = df[df["Episode"].str.startswith('S7E')]
df_S7 = df_S7.set_index('Episode')
S7 = df_S7.to_html()
print(S7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S7E1</th>
#       <td>Who Shot Mr. Burns? Part Two</td>
#       <td>Mr. Burns is laying in the hospital while the investigation into his shooter begins. Every citizen has motivation, but it's Simpson DNA that has been found.</td>
#       <td>17 Sep. 1995</td>
#       <td>9.0</td>
#       <td>3671</td>
#       <td>https://www.imdb.com/title/tt0701295/</td>
#     </tr>
#     <tr>
#       <th>S7E2</th>
#       <td>Radioactive Man</td>
# ...

# %%
df_S8 = df[df["Episode"].str.startswith('S8E')]
df_S8 = df_S8.set_index('Episode')
S8 = df_S8.to_html()
print(S8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S8E1</th>
#       <td>Treehouse of Horror VII</td>
#       <td>Bart's Siamese twin swells in the attic</td>
#       <td>27 Oct. 1996</td>
#       <td>8.5</td>
#       <td>2950</td>
#       <td>https://www.imdb.com/title/tt0779678/</td>
#     </tr>
#     <tr>
#       <th>S8E2</th>
#       <td>You Only Move Twice</td>
#       <td>After moving to another town for a new job, Homer must decide whether or not to stay when the family have a hard time with the transfer.</td>
# ...

# %%
df_S9 = df[df["Episode"].str.startswith('S9E')]
df_S9 = df_S9.set_index('Episode')
S9 = df_S9.to_html()
print(S9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S9E1</th>
#       <td>The City of New York vs. Homer Simpson</td>
#       <td>Homer must travel to New York to get his car back, which is illegally parked at World Trade Center Plaza.</td>
#       <td>21 Sep. 1997</td>
#       <td>9.0</td>
#       <td>4462</td>
#       <td>https://www.imdb.com/title/tt0701230/</td>
#     </tr>
#     <tr>
#       <th>S9E2</th>
#       <td>The Principal and the Pauper</td>
# ...

# %%
df_S10 = df[df["Episode"].str.startswith('S10E')]
df_S10 = df_S10.set_index('Episode')
S10 = df_S10.to_html()
print(S10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S10E1</th>
#       <td>Lard of the Dance</td>
#       <td>Homer and Bart try to start their own grease business</td>
#       <td>23 Aug. 1998</td>
#       <td>7.6</td>
#       <td>2162</td>
#       <td>https://www.imdb.com/title/tt0701149/</td>
#     </tr>
#     <tr>
#       <th>S10E2</th>
#       <td>The Wizard of Evergreen Terrace</td>
#       <td>Homer's midlife crisis leads to a disastrous attempt at being an inventor.</td>
#       <td>20 Sep. 1998</td>
#       <td>8.1</td>
# ...

# %%
df_S11 = df[df["Episode"].str.startswith('S11E')]
df_S11 = df_S11.set_index('Episode')
S11 = df_S11.to_html()
print(S11)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S11E1</th>
#       <td>Beyond Blunderdome</td>
#       <td>Convinced he's the only man with guts to tell him the truth, Mel Gibson insists Homer accompanies him in Hollywood to help fix his newest film project.</td>
#       <td>26 Sep. 1999</td>
#       <td>7.4</td>
#       <td>2021</td>
#       <td>https://www.imdb.com/title/tt0701069/</td>
#     </tr>
#     <tr>
#       <th>S11E2</th>
#       <td>Brother's Little Helper</td>
# ...

# %%
df_S12 = df[df["Episode"].str.startswith('S12E')]
df_S12 = df_S12.set_index('Episode')
S12 = df_S12.to_html()
print(S12)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S12E1</th>
#       <td>Treehouse of Horror XI</td>
#       <td>Homer must do one good deed to get into Heaven</td>
#       <td>1 Nov. 2000</td>
#       <td>7.6</td>
#       <td>2005</td>
#       <td>https://www.imdb.com/title/tt0763040/</td>
#     </tr>
#     <tr>
#       <th>S12E2</th>
#       <td>A Tale of Two Springfields</td>
#       <td>Springfield is split in two when Homer revolts because his area code is changed</td>
#       <td>5 Nov. 2000</td>
#       <td>7.4</td>
# ...

# %%
df_S13 = df[df["Episode"].str.startswith('S13E')]
df_S13 = df_S13.set_index('Episode')
S13 = df_S13.to_html()
print(S13)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S13E1</th>
#       <td>Treehouse of Horror XII</td>
#       <td>A gypsy puts a curse on Homer</td>
#       <td>6 Nov. 2001</td>
#       <td>7.6</td>
#       <td>1955</td>
#       <td>https://www.imdb.com/title/tt0701284/</td>
#     </tr>
#     <tr>
#       <th>S13E2</th>
#       <td>The Parent Rap</td>
#       <td>After Bart takes a joyride in a police car, a judge orders him to be tethered to Homer at all times.</td>
#       <td>11 Nov. 2001</td>
#       <td>7.1</td>
#       <td>1606</td>
# ...

# %%
df_S14 = df[df["Episode"].str.startswith('S14E')]
df_S14 = df_S14.set_index('Episode')
S14 = df_S14.to_html()
print(S14)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S14E1</th>
#       <td>Treehouse of Horror XIII</td>
#       <td>Homer clones himself with a magic hammock</td>
#       <td>3 Nov. 2002</td>
#       <td>7.6</td>
#       <td>1834</td>
#       <td>https://www.imdb.com/title/tt0763041/</td>
#     </tr>
#     <tr>
#       <th>S14E2</th>
#       <td>How I Spent My Strummer Vacation</td>
# ...

# %%
df_S15 = df[df["Episode"].str.startswith('S15E')]
df_S15 = df_S15.set_index('Episode')
S15 = df_S15.to_html()
print(S15)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S15E1</th>
#       <td>Treehouse of Horror XIV</td>
#       <td>First, Homer kills the Grim Reaper and takes his place in Reaper Madness. Then, Professor Frink's father is revived, only to kill people and steal their organs in Frinkenstein. Finally, Bart and Milhouse get a stop watch that can stop time in Stop the World, I Want To Goof Off.</td>
#       <td>2 Nov. 2003</td>
#       <td>7.5</td>
#       <td>1780</td>
#       <td>https://www.imdb.com/title/tt0701285/</td>
#     </tr>
#     <tr>
# ...

# %%
df_S16 = df[df["Episode"].str.startswith('S16E')]
df_S16 = df_S16.set_index('Episode')
S16 = df_S16.to_html()
print(S16)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S16E1</th>
#       <td>Treehouse of Horror XV</td>
#       <td>Ned gains the power to foresee people's deaths</td>
#       <td>7 Nov. 2004</td>
#       <td>7.4</td>
#       <td>1679</td>
#       <td>https://www.imdb.com/title/tt0701286/</td>
#     </tr>
#     <tr>
#       <th>S16E2</th>
#       <td>All's Fair in Oven War</td>
#       <td>Homer buys Marge a new kitchen, and Marge likes cooking in the new kitchen so much she attends the Ovenfresh Bakeoff.</td>
#       <td>14 Nov. 2004</td>
# ...

# %%
df_S17 = df[df["Episode"].str.startswith('S17E')]
df_S17 = df_S17.set_index('Episode')
S17 = df_S17.to_html()
print(S17)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S17E1</th>
#       <td>The Bonfire of the Manatees</td>
#       <td>When Marge leaves Homer because he allowed an adult movie being shot in their house, she seeks self fulfillment in protecting manatees.</td>
#       <td>11 Sep. 2005</td>
#       <td>6.2</td>
#       <td>1439</td>
#       <td>https://www.imdb.com/title/tt0701071/</td>
#     </tr>
#     <tr>
#       <th>S17E2</th>
#       <td>The Girl Who Slept Too Little</td>
# ...

# %%
df_S18 = df[df["Episode"].str.startswith('S18E')]
df_S18 = df_S18.set_index('Episode')
S18 = df_S18.to_html()
print(S18)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S18E1</th>
#       <td>The Mook, the Chef, the Wife and Her Homer</td>
#       <td>When Fat Tony has to take a time-out due to a whacking attempt, Homer and Bart take over the business.</td>
#       <td>10 Sep. 2006</td>
#       <td>7.6</td>
#       <td>1655</td>
#       <td>https://www.imdb.com/title/tt0831239/</td>
#     </tr>
#     <tr>
#       <th>S18E2</th>
#       <td>Jazzy &amp; The Pussycats</td>
# ...

# %%
df_S19 = df[df["Episode"].str.startswith('S19E')]
df_S19 = df_S19.set_index('Episode')
S19 = df_S19.to_html()
print(S19)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S19E1</th>
#       <td>He Loves to Fly and He D'ohs</td>
#       <td>Homer falls in love with private planes after taking a flight to Chicago with Mr. Burns. So Marge hires Homer a "life manager" to help him think positively and find a job that will allow him to fly for a living.</td>
#       <td>23 Sep. 2007</td>
#       <td>6.7</td>
#       <td>1467</td>
#       <td>https://www.imdb.com/title/tt1103798/</td>
#     </tr>
#     <tr>
#       <th>S19E2</th>
#       <td>Homer of Seville</td>
# ...

# %%
df_S20 = df[df["Episode"].str.startswith('S20E')]
df_S20 = df_S20.set_index('Episode')
S20 = df_S20.to_html()
print(S20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S20E1</th>
#       <td>Sex, Pies and Idiot Scrapes</td>
#       <td>Homer and Ned go into business together as bounty hunters, and Marge takes a job at an erotic bakery.</td>
#       <td>28 Sep. 2008</td>
#       <td>7.2</td>
#       <td>1597</td>
#       <td>https://www.imdb.com/title/tt1289258/</td>
#     </tr>
#     <tr>
#       <th>S20E2</th>
#       <td>Lost Verizon</td>
# ...

# %%
df_S21 = df[df["Episode"].str.startswith('S21E')]
df_S21 = df_S21.set_index('Episode')
S21 = df_S21.to_html()
print(S21)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S21E1</th>
#       <td>Homer the Whopper</td>
#       <td>A Hollywood studio makes a movie based on Comic Book Guy's comic book character "Everyman," and Homer is cast in the lead. However, Homer's weight fluctuations cause problems for the production.</td>
#       <td>27 Sep. 2009</td>
#       <td>7.1</td>
#       <td>1471</td>
#       <td>https://www.imdb.com/title/tt1502337/</td>
#     </tr>
#     <tr>
#       <th>S21E2</th>
#       <td>Bart Gets a 'Z'</td>
# ...

# %%
df_S22 = df[df["Episode"].str.startswith('S22E')]
df_S22 = df_S22.set_index('Episode')
S22 = df_S22.to_html()
print(S22)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S22E1</th>
#       <td>Elementary School Musical</td>
#       <td>While Homer and Bart accompany Krusty to Oslo so he can receive the Nobel Peace Prize, Marge enrolls Lisa for a week in performing arts camp.</td>
#       <td>26 Sep. 2010</td>
#       <td>6.2</td>
#       <td>1381</td>
#       <td>https://www.imdb.com/title/tt1628648/</td>
#     </tr>
#     <tr>
#       <th>S22E2</th>
#       <td>Loan-a Lisa</td>
# ...

# %%
df_S23 = df[df["Episode"].str.startswith('S23E')]
df_S23 = df_S23.set_index('Episode')
S23 = df_S23.to_html()
print(S23)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S23E1</th>
#       <td>The Falcon and the D'Ohman</td>
#       <td>Homer tries to befriend the new security guard at the nuclear power plant, who for some unknown reason isn't interested and keeps having flashbacks to his violent past as a government agent.</td>
#       <td>25 Sep. 2011</td>
#       <td>7.1</td>
#       <td>1386</td>
#       <td>https://www.imdb.com/title/tt2000327/</td>
#     </tr>
#     <tr>
#       <th>S23E2</th>
#       <td>Bart Stops to Smell the Roosevelts</td>
# ...

# %%
df_S24 = df[df["Episode"].str.startswith('S24E')]
df_S24 = df_S24.set_index('Episode')
S24 = df_S24.to_html()
print(S24)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S24E1</th>
#       <td>Moonshine River</td>
#       <td>The Simpsons go back to New York City so that Bart can find his old girlfriend Mary Spuckler. Meanwhile, Lisa and Marge spend the trip trying to take in New York culture on the cheap.</td>
#       <td>30 Sep. 2012</td>
#       <td>6.4</td>
#       <td>1283</td>
#       <td>https://www.imdb.com/title/tt2289606/</td>
#     </tr>
#     <tr>
#       <th>S24E2</th>
#       <td>Treehouse of Horror XXIII</td>
# ...

# %%
df_S25 = df[df["Episode"].str.startswith('S25E')]
df_S25 = df_S25.set_index('Episode')
S25 = df_S25.to_html()
print(S25)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S25E1</th>
#       <td>Homerland</td>
#       <td>Homer returns from a nuclear power convention a changed man, and Lisa begins to suspect that he has become a domestic terrorist.</td>
#       <td>29 Sep. 2013</td>
#       <td>6.9</td>
#       <td>1338</td>
#       <td>https://www.imdb.com/title/tt2932788/</td>
#     </tr>
#     <tr>
#       <th>S25E2</th>
#       <td>Treehouse of Horror XXIV</td>
# ...

# %%
df_S26 = df[df["Episode"].str.startswith('S26E')]
df_S26 = df_S26.set_index('Episode')
S26 = df_S26.to_html()
print(S26)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S26E1</th>
#       <td>Clown in the Dumps</td>
#       <td>Krusty has a crisis of conscience and retires from show business after his father dies before ever approving of his career. Meanwhile, Lisa becomes worried about Homer's health and life expectancy.</td>
#       <td>28 Sep. 2014</td>
#       <td>5.7</td>
#       <td>1332</td>
#       <td>https://www.imdb.com/title/tt3707816/</td>
#     </tr>
#     <tr>
#       <th>S26E2</th>
#       <td>The Wreck of the Relationship</td>
# ...

# %%
df_S27 = df[df["Episode"].str.startswith('S27E')]
df_S27 = df_S27.set_index('Episode')
S27 = df_S27.to_html()
print(S27)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S27E1</th>
#       <td>Every Man's Dream</td>
#       <td>Marge decides it's finally time to separate from Homer, and quickly moves on with her life. Homer is initially devastated, but soon stumbles into a romance with a younger woman.</td>
#       <td>27 Sep. 2015</td>
#       <td>5.7</td>
#       <td>1269</td>
#       <td>https://www.imdb.com/title/tt4341176/</td>
#     </tr>
#     <tr>
#       <th>S27E2</th>
#       <td>'Cue Detective</td>
# ...

# %%
df_S28 = df[df["Episode"].str.startswith('S28E')]
df_S28 = df_S28.set_index('Episode')
S28 = df_S28.to_html()
print(S28)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S28E1</th>
#       <td>Monty Burns' Fleeing Circus</td>
#       <td>Mr. Burns puts on a variety show at the Springfield Bowl.</td>
#       <td>25 Sep. 2016</td>
#       <td>6.0</td>
#       <td>951</td>
#       <td>https://www.imdb.com/title/tt5718172/</td>
#     </tr>
#     <tr>
#       <th>S28E2</th>
#       <td>Friends and Family</td>
#       <td>Homer finds a new friend in a woman who acts just like him when Mr. Burns hires the other Simpsons as his live-in virtual reality family.</td>
# ...

# %%
df_S29 = df[df["Episode"].str.startswith('S29E')]
df_S29 = df_S29.set_index('Episode')
S29 = df_S29.to_html()
print(S29)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S29E1</th>
#       <td>The Serfsons</td>
#       <td>In a medieval world, Lisa is forced to use illegal magic when Marge's mother is turned into an Ice Walker.</td>
#       <td>1 Oct. 2017</td>
#       <td>6.8</td>
#       <td>1220</td>
#       <td>https://www.imdb.com/title/tt7156270/</td>
#     </tr>
#     <tr>
#       <th>S29E2</th>
#       <td>Springfield Splendor</td>
#       <td>Lisa's sad experience is adapted into a graphic novel, which becomes a Broadway show.</td>
# ...

# %%
df_S30 = df[df["Episode"].str.startswith('S30E')]
df_S30 = df_S30.set_index('Episode')
S30 = df_S30.to_html()
print(S30)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S30E1</th>
#       <td>Bart's Not Dead</td>
#       <td>Bart ends up in the hospital after taking a dare and lies about going to heaven to cover it up, but Homer takes a deal with Christian producers to make a movie about it.</td>
#       <td>30 Sep. 2018</td>
#       <td>6.2</td>
#       <td>1045</td>
#       <td>https://www.imdb.com/title/tt6225298/</td>
#     </tr>
#     <tr>
#       <th>S30E2</th>
#       <td>Heartbreak Hotel</td>
# ...

# %%
df_S31 = df[df["Episode"].str.startswith('S31E')]
df_S31 = df_S31.set_index('Episode')
S31 = df_S31.to_html()
print(S31)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S31E1</th>
#       <td>The Winter of Our Monetized Content</td>
#       <td>Bart and Homer become social media celebrities when a video of them fighting goes viral</td>
#       <td>29 Sep. 2019</td>
#       <td>5.9</td>
#       <td>997</td>
#       <td>https://www.imdb.com/title/tt10933664/</td>
#     </tr>
#     <tr>
#       <th>S31E2</th>
#       <td>Go Big or Go Homer</td>
# ...

# %%
df_S32 = df[df["Episode"].str.startswith('S32E')]
df_S32 = df_S32.set_index('Episode')
S32 = df_S32.to_html()
print(S32)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S32E1</th>
#       <td>Undercover Burns</td>
#       <td>Mr. Burns goes undercover at the power plant as an employee named Fred and befriends Homer and the gang, but a jealous Smithers plots to bring the old Burns back.</td>
#       <td>27 Sep. 2020</td>
#       <td>6.5</td>
#       <td>886</td>
#       <td>https://www.imdb.com/title/tt9761050/</td>
#     </tr>
#     <tr>
#       <th>S32E2</th>
#       <td>I, Carumbus</td>
# ...

# %%
df_S33 = df[df["Episode"].str.startswith('S33E')]
df_S33 = df_S33.set_index('Episode')
S33 = df_S33.to_html()
print(S33)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titre</th>
#       <th>Résumé</th>
#       <th>Date de sortie</th>
#       <th>Note IMDB</th>
#       <th>Nombre d'avis IMDB</th>
#       <th>Lien vers l'épisode</th>
#     </tr>
#     <tr>
#       <th>Episode</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>S33E1</th>
#       <td>The Star of the Backstage</td>
#       <td>Marge stages a revival of a musical from high school, but her pleasant memories are threatened by the return of her old rival.</td>
#       <td>26 Sep. 2021</td>
#       <td>4.3</td>
#       <td>1003</td>
#       <td>https://www.imdb.com/title/tt14167092/</td>
#     </tr>
#     <tr>
#       <th>S33E2</th>
#       <td>Bart's in Jail!</td>
# ...

# %%
#from itables import init_notebook_mode, show
#init_notebook_mode(all_interactive=True)
#show(df)

# %%
#html = df.to_html()
#print(html)
