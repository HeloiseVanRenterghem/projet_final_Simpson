# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df_imdb = pd.read_excel("imdb_cleaned.xlsx", index_col=0)
df_imdb
# Out:
#     season episode  episode_serie                              title  \
# 0       S1      E1              1  Simpsons Roasting on an Open Fire
# 1       S1      E2              2                    Bart the Genius
# 2       S1      E3              3                    Homer's Odyssey
# 3       S1      E4              4      There's No Disgrace Like Home
# 4       S1      E5              5                   Bart the General
# ..     ...     ...            ...                                ...
# 722    S33     E18            723           My Octopus and a Teacher
# 723    S33     E19            724         Girls Just Shauna Have Fun
# 724    S33     E20            725                   Marge the Meanie
# 725    S33     E21            726                     Meat Is Murder
# 726    S33     E22            727                     Poorhouse Rock
#
#                                              summaries      airdates  ratings  \
# ...

# %% [markdown]
# ## Nb d'occurences des membres de la famille Simpson dans les titres et résumés des épisodes

# %%
nb_homer_title = df_imdb["title"].str.contains('Homer').value_counts().loc[True]
nb_homer_title
# Out:
# 56

# %%
nb_marge_title = df_imdb["title"].str.contains('Marge').value_counts().loc[True]
nb_marge_title
# Out:
# 23

# %%
nb_bart_title = df_imdb["title"].str.contains('Bart').value_counts().loc[True]
nb_bart_title
# Out:
# 48

# %%
nb_lisa_title = df_imdb["title"].str.contains('Lisa').value_counts().loc[True]
nb_lisa_title
# Out:
# 42

# %%
nb_maggie_title = df_imdb["title"].str.contains('Maggie').value_counts().loc[True]
nb_maggie_title
# Out:
# 3

# %%
nb_famille_title = [nb_homer_title, nb_marge_title, nb_bart_title, nb_lisa_title, nb_maggie_title]
nb_famille_title
# Out:
# [56, 23, 48, 42, 3]

# %%
nb_homer_summary = df_imdb["summaries"].str.contains('Homer').value_counts().loc[True]
nb_homer_summary
# Out:
# 407

# %%
nb_marge_summary = df_imdb["summaries"].str.contains('Marge').value_counts().loc[True]
nb_marge_summary
# Out:
# 181

# %%
nb_bart_summary = df_imdb["summaries"].str.contains('Bart').value_counts().loc[True]
nb_bart_summary
# Out:
# 260

# %%
nb_lisa_summary = df_imdb["summaries"].str.contains('Lisa').value_counts().loc[True]
nb_lisa_summary
# Out:
# 205

# %%
nb_maggie_summary = df_imdb["summaries"].str.contains('Maggie').value_counts().loc[True]
nb_maggie_summary
# Out:
# 25

# %%
nb_famille_summary = [nb_homer_summary, nb_marge_summary, nb_bart_summary, nb_lisa_summary, nb_maggie_summary]
nb_famille_summary
# Out:
# [407, 181, 260, 205, 25]

# %%
mb_famille = ["Homer", "Marge", "Bart", "Lisa", "Maggie"]

# %%
df_famille = pd.DataFrame(mb_famille)
df_famille["nb_in_title"] = nb_famille_title
df_famille["nb_in_summary"] = nb_famille_summary
df_famille = df_famille.sort_values(by=['nb_in_title'], ascending=False)
df_famille
# Out:
#         0  nb_in_title  nb_in_summary
# 0   Homer           56            407
# 2    Bart           48            260
# 3    Lisa           42            205
# 1   Marge           23            181
# 4  Maggie            3             25

# %%
print(df_famille.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>nb_in_title</th>
#       <th>nb_in_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Homer</td>
#       <td>56</td>
#       <td>407</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bart</td>
#       <td>48</td>
#       <td>260</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Lisa</td>
#       <td>42</td>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Marge</td>
#       <td>23</td>
#       <td>181</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Maggie</td>
#       <td>3</td>
#       <td>25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analyses démographiques par sexe

# %%
df_characters = pd.read_csv("simpsons_characters.csv")
df_characters
# Out:
#         id              name   normalized_name gender
# 0        7          Children          children    NaN
# 1       12  Mechanical Santa  mechanical santa    NaN
# 2       13        Tattoo Man        tattoo man    NaN
# 3       16  DOCTOR ZITSOFSKY  doctor zitsofsky    NaN
# 4       20          Students          students    NaN
# ...    ...               ...               ...    ...
# 6717  5222    Ron Rabinowitz    ron rabinowitz      m
# 6718  5728    Martha Stewart    martha stewart      f
# 6719  1770   Officer Goodman   officer goodman      m
# 6720  1634      Evan Conover      evan conover      m
# 6721  1868     Agent Johnson     agent johnson      m
#
# [6722 rows x 4 columns]

# %%
df_characters['id'].nunique()
# Out:
# 6722

# %%
gender_repartition = df_characters["gender"].value_counts().to_frame()
gender_repartition
# Out:
#    gender
# m     252
# f      71

# %%
labels = ['Hommes','Femmes']

gender_repartition.plot.pie(y='gender', figsize=(7, 7), autopct='%1.0f%%', labels=labels, colors = ['#C1EFFF', '#FFB3B3'])

plt.ylabel('')
ax = plt.subplot(111)
ax.get_legend().remove()

plt.title('Répartition du nombre de personnages par sexe', x=0.5, y=0.95, fontweight="bold")

#plt.savefig('nb_gender.png')

plt.show()

# %% [markdown]
# ## Analyses démographiques par âge

# %%
df_characters_age = pd.read_csv("simpsons_characters_age.csv", index_col=0)
df_characters_age
# Out:
#                                      characters    categ
# 0                 "Something New" Spuckler Baby   Babies
# 1                         Bart and Darcy's baby   Babies
# 2                                     Baby Bear   Babies
# 3                          Bouncing Battle Baby   Babies
# 4                                  Axel Bouvier   Babies
# ..                                          ...      ...
# 483  Zeke Simpson (A Trip to Simpsons Mountain)  Seniors
# 484                                       Zelda  Seniors
# 485                                 Aunt Gladys  Seniors
# 486                             Zza-Zza Simpson  Seniors
# 487                                Mr. Zzyzwicz  Seniors
#
# [4139 rows x 2 columns]

# %%
doublons = df_characters_age[df_characters_age.characters.duplicated(keep=False)].sort_values(by=['characters'])
print(doublons['characters'].value_counts())
nb_persos_doublons = len(doublons) / 2 - 1
nb_persos_doublons
# Out:
# Mayor Quimby's secret family    3
# Eliza Simpson                   3
# "Old Tut" Simpson               2
# Mr. Parkfield                   2
# NASA Representative             2
#                                ..
# Frink's Mother                  2
# Freddy Quimby                   2
# Fred Rogers                     2
# Fred Kanneke                    2
# Zelda                           2
# Name: characters, Length: 439, dtype: int64
# 439.0

# %%
repartition_age = df_characters_age["categ"].value_counts().to_frame()
repartition_age
# Out:
#            categ
# Adults      2875
# Children     606
# Seniors      486
# Teenagers    100
# Babies        72

# %%
babies = repartition_age.at["Babies", "categ"] / repartition_age.sum()
children = repartition_age.at["Children", "categ"] / repartition_age.sum()
teenagers = repartition_age.at["Teenagers", "categ"] / repartition_age.sum()
adults = repartition_age.at["Adults", "categ"] / repartition_age.sum()
seniors = repartition_age.at["Seniors", "categ"] / repartition_age.sum()
repartition_age["percentage"] = [adults[0], children[0], seniors[0], teenagers[0], babies[0]]
repartition_age
# Out:
#            categ  percentage
# Adults      2875    0.694612
# Children     606    0.146412
# Seniors      486    0.117420
# Teenagers    100    0.024160
# Babies        72    0.017396

# %%
repartition_age = repartition_age.reindex(index = ['Babies','Children','Teenagers', 'Adults', 'Seniors'])
repartition_age
# Out:
#            categ  percentage
# Babies        72    0.017396
# Children     606    0.146412
# Teenagers    100    0.024160
# Adults      2875    0.694612
# Seniors      486    0.117420

# %%
repartition_age[['percentage']].T.plot.barh(stacked=True, figsize=(12, 5), use_index=False, legend=True, color = ['#CAF0F8', '#90E0EF', '#00B4D8', '#0077B6', '#03045E'])

plt.xlim([0, 1])
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', bottom=False, top=False, labelbottom=False)

ax = plt.subplot(111)
mylabels = ['Babies (1,7%)','Children (14,6%)','Teenagers (2,4%)', 'Adults (69,5%)', 'Seniors (11,7%)']
ax.legend(labels=mylabels, loc='lower center', bbox_to_anchor=(0.5, 0.1), ncol=5, fancybox=True, shadow=True)

plt.title("Répartition du nombre de personnages par groupes d'âges", x=0.5, y=0.8, fontweight="bold")

#plt.savefig('nb_age.png')

plt.show()

# %% [markdown]
# ## Nb de lignes de dialogue des persos

# %%
df_script_lines = pd.read_csv("simpsons_script_lines.csv")
df_script_lines
# Out:
# /var/folders/r7/nyn0pbkd469dh1skmjprpkt80000gn/T/ipykernel_3597/2260587107.py:1: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_script_lines = pd.read_csv("simpsons_script_lines.csv")
#           id  episode_id  number  \
# 0       9549          32     209
# 1       9550          32     210
# 2       9551          32     211
# 3       9552          32     212
# 4       9553          32     213
# ...      ...         ...     ...
# 158266  9544          32     204
# 158267  9545          32     205
# 158268  9546          32     206
# 158269  9547          32     207
# 158270  9548          32     208
#
#                                                  raw_text timestamp_in_ms  \
# 0       Miss Hoover: No, actually, it was a little of ...          848000
# 1       Lisa Simpson: (NEAR TEARS) Where's Mr. Bergstrom?          856000
# 2       Miss Hoover: I don't know. Although I'd sure l...          856000
# ...

# %%
df_script_lines["episode_id"].value_counts()
# Out:
# 228    395
# 1      377
# 231    376
# 271    375
# 28     367
#       ...
# 138    208
# 568    206
# 554    204
# 286    146
# 189     79
# Name: episode_id, Length: 564, dtype: int64

# %%
# jusqu'à S26E16
df_script_lines["episode_id"].max()
# Out:
# 568

# %%
characters_lines = df_script_lines
characters_lines['character_id'] = pd.to_numeric(df_script_lines['character_id'], errors="coerce").fillna(0)
characters_lines_values = characters_lines["character_id"].astype(int).value_counts()
characters_lines_values = characters_lines_values.drop(index=0)
characters_lines_values
# Out:
# 2       30108
# 1       14265
# 8       13969
# 9       11641
# 15       3207
#         ...
# 4324        1
# 4325        1
# 1791        1
# 4328        1
# 3640        1
# Name: character_id, Length: 6721, dtype: int64

# %%
df_characters_lines = characters_lines_values.to_frame()
df_characters_lines
# Out:
#       character_id
# 2            30108
# 1            14265
# 8            13969
# 9            11641
# 15            3207
# ...            ...
# 4324             1
# 4325             1
# 1791             1
# 4328             1
# 3640             1
#
# [6721 rows x 1 columns]

# %%
df_characters_lines["character_id"].value_counts()[1]
# Out:
# 3034

# %%
df_characters_lines_100 = df_characters_lines.head(100).copy()
df_characters_lines_100['id'] = df_characters_lines_100.index
df_characters_lines_100 = df_characters_lines_100.rename(columns={"character_id": "nb_lines"})
df_characters_lines_100 = df_characters_lines_100[['id', 'nb_lines']]
df_characters_lines_100
# Out:
#         id  nb_lines
# 2        2     30108
# 1        1     14265
# 8        8     13969
# 9        9     11641
# 15      15      3207
# ...    ...       ...
# 1197  1197        72
# 218    218        69
# 6190  6190        68
# 238    238        68
# 618    618        68
#
# [100 rows x 2 columns]

# %%
df_characters_merged = df_characters_lines_100.merge(df_characters, how='inner', on='id')
df_characters_merged
# Out:
#       id  nb_lines                 name     normalized_name gender
# 0      2     30108        Homer Simpson       homer simpson      m
# 1      1     14265        Marge Simpson       marge simpson      f
# 2      8     13969         Bart Simpson        bart simpson      m
# 3      9     11641         Lisa Simpson        lisa simpson      f
# 4     15      3207  C. Montgomery Burns  c montgomery burns      m
# ..   ...       ...                  ...                 ...    ...
# 95  1197        72     George H.W. Bush      george hw bush      m
# 96   218        69             Director            director      m
# 97  6190        68          Dan Gillick         dan gillick      m
# 98   238        68                Marty               marty      m
# 99   618        68          Townspeople         townspeople    NaN
#
# [100 rows x 5 columns]

# %%
df_characters_merged["gender"].value_counts()
# Out:
# m    72
# f    19
# Name: gender, dtype: int64

# %%
dict_lines = dict(zip(df_characters_merged["name"], df_characters_merged["nb_lines"]))

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import random

# %%
nb_lines_mask = np.array(Image.open('/Users/heloisevanrenterghem/Documents/THPprojets/Simpsons/donut.jpeg'))

# %%
def pink_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(324, 100%%, %50d%%)" % random.randint(40, 90)

# %%
wordcloud = WordCloud(font_path = 'Homer_Simpson_Revised.ttf', width=3000, height=2000, background_color="white", mask=nb_lines_mask, colormap='spring', prefer_horizontal=1).generate_from_frequencies(dict_lines)
wordcloud.recolor(color_func = pink_color_func)
plt.figure(figsize=[10,10])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Nombre de lignes de dialogue par personnage', x=0.5, y=1, fontweight="bold")
#plt.savefig('characters_nb_lines_wc.png')
plt.show()

# %% [markdown]
# ## Mise en relation avec le classement des persos

# %%
df_characters_ranked = pd.read_csv("simpsons_characters_ranked.csv")
df_characters_ranked = df_characters_ranked.iloc[::-1].head(15)
df_characters_ranked
# Out:
#     rank                  character
# 49     1              Marge Simpson
# 48     2              Homer Simpson
# 47     3               Lisa Simpson
# 46     4               Ned Flanders
# 45     5        Milhouse Van Houten
# 44     6            Seymour Skinner
# 43     7               Bart Simpson
# 42     8                Moe Syszlak
# 41     9     Apu Nahasapeemapetilon
# 40    10           Krusty the Clown
# 39    11   Charles Montgomery Burns
# 38    12               Sideshow Bob
# 37    13            Abraham Simpson
# 36    14             Edna Krabappel
# 35    15               Ralph Wiggum

# %%
df_characters_ranked["character"] = df_characters_ranked["character"].str.strip()
df_characters_merged['name'] = df_characters_merged['name'].replace(['Moe Szyslak', 'Krusty the Clown', 'C. Montgomery Burns', 'Grampa Simpson', 'Edna Krabappel-Flanders'],['Moe Syszlak', 'Krusty the Clown', 'Charles Montgomery Burns', 'Abraham Simpson', 'Edna Krabappel'])

# %%
df_characters_rank_merged = df_characters_ranked.merge(df_characters_merged, how='left', left_on='character', right_on='name')
df_characters_rank_merged
# Out:
#     rank                 character   id  nb_lines                      name  \
# 0      1             Marge Simpson    1     14265             Marge Simpson
# 1      2             Homer Simpson    2     30108             Homer Simpson
# 2      3              Lisa Simpson    9     11641              Lisa Simpson
# 3      4              Ned Flanders   11      2145              Ned Flanders
# 4      5       Milhouse Van Houten   25      1911       Milhouse Van Houten
# 5      6           Seymour Skinner    3      2443           Seymour Skinner
# 6      7              Bart Simpson    8     13969              Bart Simpson
# 7      8               Moe Syszlak   17      2864               Moe Syszlak
# 8      9    Apu Nahasapeemapetilon  208      1006    Apu Nahasapeemapetilon
# 9     10          Krusty the Clown  139      1789          Krusty the Clown
# 10    11  Charles Montgomery Burns   15      3207  Charles Montgomery Burns
# ...

# %%
df_characters_rank_merged['rank'] = df_characters_rank_merged['rank'].map(str)
df_characters_rank_merged['Personnage'] = df_characters_rank_merged['rank'] + ' - ' + df_characters_rank_merged['character']
df_characters_rank_merged_hist = df_characters_rank_merged[['Personnage', 'nb_lines']]
df_characters_rank_merged_hist = df_characters_rank_merged_hist.set_index('Personnage')
df_characters_rank_merged_hist
# Out:
#                                nb_lines
# Personnage
# 1 - Marge Simpson                 14265
# 2 - Homer Simpson                 30108
# 3 - Lisa Simpson                  11641
# 4 - Ned Flanders                   2145
# 5 - Milhouse Van Houten            1911
# 6 - Seymour Skinner                2443
# 7 - Bart Simpson                  13969
# 8 - Moe Syszlak                    2864
# 9 - Apu Nahasapeemapetilon         1006
# 10 - Krusty the Clown              1789
# 11 - Charles Montgomery Burns      3207
# 12 - Sideshow Bob                   577
# 13 - Abraham Simpson               1957
# 14 - Edna Krabappel                 781
# 15 - Ralph Wiggum                   508

# %%
df_characters_rank_merged_hist.plot(kind='bar', figsize=(10, 7), legend=False, edgecolor='#F5C024', color="#92D4F8", linewidth=2)

plt.xlabel('Meilleurs personnages (selon Looper)')
plt.ylabel('Nombre de lignes de dialogue')

plt.title('Nombre de lignes de dialogue pour les 15 meilleurs personnages', x=0.5, y=1, fontweight="bold")

#plt.savefig('characters_nb_lines_rank.png')

plt.show()

# %% [markdown]
# ## Les personnages du monde réel

# %%
df_real_world_characters = pd.read_csv("real_world_characters.csv", index_col=0)
df_real_world_characters
# Out:
#            real_world_characters
# 0      "Stone Cold" Steve Austin
# 1            'N Sync (character)
# 2                  3 Little Pigs
# 3            50 Cent (character)
# 4                     Aaron Burr
# ..                           ...
# 432                       Yahweh
# 433   Yeardley Smith (character)
# 434   Muhammad Yunus (character)
# 435                 Richard Zare
# 436  Mark Zuckerberg (character)
#
# [437 rows x 1 columns]

# %%
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Category:')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Buzz Aldrin')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Bret "The Hit-man" Hart (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Bette Midler (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('List of guest stars')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('George Burns (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Gabriel (Angel)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('God')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('James Woods')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Luke Perry (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Jesus Christ')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Goliath')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith("Homer's XXXercise Tape")]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith("Cap'n Crunch")]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('James Woods (Family Guy)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Blackbeard')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Big Bird')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Cleatus the Football Robot')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Clippy')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Colonel Sanders')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Count von Count')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Fan Man')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Dr. Demento (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Behind the Laughter/References')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Mary (mother of Tom Sr and Joey Lauro)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Neil deGrasse Tyson (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Oscar the Grouch')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Pazuzu')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Pharrell Williams (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Tony Blair (character)')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('real_world_characters')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('User:')]
df_real_world_characters = df_real_world_characters.loc[~df_real_world_characters['real_world_characters'].str.startswith('Yahweh')]
df_real_world_characters
# Out:
#            real_world_characters
# 0      "Stone Cold" Steve Austin
# 1            'N Sync (character)
# 2                  3 Little Pigs
# 3            50 Cent (character)
# 4                     Aaron Burr
# ..                           ...
# 431  Woody Harrelson (character)
# 433   Yeardley Smith (character)
# 434   Muhammad Yunus (character)
# 435                 Richard Zare
# 436  Mark Zuckerberg (character)
#
# [400 rows x 1 columns]

# %%
df_real_world_characters = df_real_world_characters.replace("character", "", regex=True).replace("grave", "", regex=True).replace(r'[()]+', '', regex=True)
df_real_world_characters["Nb"] = [1] * 400
df_real_world_characters
# Out:
#          real_world_characters  Nb
# 0    "Stone Cold" Steve Austin   1
# 1                     'N Sync    1
# 2                3 Little Pigs   1
# 3                     50 Cent    1
# 4                   Aaron Burr   1
# ..                         ...  ..
# 431           Woody Harrelson    1
# 433            Yeardley Smith    1
# 434            Muhammad Yunus    1
# 435               Richard Zare   1
# 436           Mark Zuckerberg    1
#
# [400 rows x 2 columns]

# %%
dict_real_world_characters = dict(zip(df_real_world_characters["real_world_characters"], df_real_world_characters["Nb"]))

import os
from os import path
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
real_world_characters_mask = np.array(Image.open(path.join(d, '/Users/heloisevanrenterghem/Documents/THPprojets/Simpsons/earth.png')))

image_colors = ImageColorGenerator(real_world_characters_mask)

# %%
wordcloud2 = WordCloud(font_path = 'Homer_Simpson_Revised.ttf', width=3000, height=3000, background_color="white", mask=real_world_characters_mask, min_font_size=21, max_font_size=21, prefer_horizontal=1).generate_from_frequencies(dict_real_world_characters)
wordcloud2.recolor(color_func = image_colors)
plt.figure(figsize=[9,9])
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.title('Personnages du monde réel', x=0.5, y=1, fontweight="bold")
#plt.savefig('characters_real_world.png')
plt.show()
